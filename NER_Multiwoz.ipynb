# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
nltk.download('averaged_perceptron_tagger')
import pandas as pd
import json
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /mnt/workspace/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Apply word tokenization and part-of-speech tagging

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %% [markdown]
# ## define the pattern

# %%
result= open("result.txt","w+")
if f.mode == 'r':
    print('file opened')
result.write("~[Location]\n")
# Out:
# file opened
# 12

# %%
#pattern = 'NP: {<DT>?<JJ>*<NN>}'
pattern = '~[Location]:{<from>?<NNP>|<TO>?<NNP>}'

# %%
with open('train_data.json', 'r') as f:
    dict_json_weighted = json.load(f)
object_1 = list(dict_json_weighted.keys())[4]
for i in range(len(dict_json_weighted[object_1]['log'])):
    print(dict_json_weighted[object_1]['log'][i]['text'])
    sent = preprocess(dict_json_weighted[object_1]['log'][i]['text'])
    print(sent)
    for j in range(len(sent)):
        if sent[j][0]=='from' or sent[j][0]=='to':
            print(sent[j+1][0])
            result.write("    "+sent[j+1][0]+"\n")
            print (sent[j])
    
    cp = nltk.RegexpParser(pattern)
    cs = cp.parse(sent)
    print(cs)
    print('*****************************************')
# Out:
# I need to go from Cambridge to Peterbourgh Saturday.
# [('I', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('go', 'VB'), ('from', 'IN'), ('Cambridge', 'NNP'), ('to', 'TO'), ('Peterbourgh', 'NNP'), ('Saturday', 'NNP'), ('.', '.')]
# go
# ('to', 'TO')
# Cambridge
# ('from', 'IN')
# Peterbourgh
# ('to', 'TO')
# (S
#   I/PRP
#   need/VBP
#   to/TO
#   go/VB
#   from/IN
#   (~[Location] Cambridge/NNP)
#   (~[Location] to/TO Peterbourgh/NNP)
#   (~[Location] Saturday/NNP)
#   ./.)
# *****************************************
# Tr7310 is leaving from cambridge at 05:06 and arriving at peterborough at 05:56 for 13.20
# [('Tr7310', 'NNP'), ('is', 'VBZ'), ('leaving', 'VBG'), ('from', 'IN'), ('cambridge', 'NN'), ('at', 'IN'), ('05:06', 'CD'), ('and', 'CC'), ('arriving', 'VBG'), ('at', 'IN'), ('peterborough', 'NN'), ('at', 'IN'), ('05:56', 'CD'), ('for', 'IN'), ('13.20', 'CD')]
# cambridge
# ('from', 'IN')
# (S
#   (~[Location] Tr7310/NNP)
#   is/VBZ
#   leaving/VBG
#   from/IN
#   cambridge/NN
#   at/IN
#   05:06/CD
#   and/CC
#   arriving/VBG
#   at/IN
#   peterborough/NN
#   at/IN
#   05:56/CD
#   for/IN
#   13.20/CD)
# *****************************************
# I'm sorry. The train needs to going to Cambridge from Peterborough.
# [('I', 'PRP'), ("'m", 'VBP'), ('sorry', 'JJ'), ('.', '.'), ('The', 'DT'), ('train', 'NN'), ('needs', 'NNS'), ('to', 'TO'), ('going', 'VBG'), ('to', 'TO'), ('Cambridge', 'NNP'), ('from', 'IN'), ('Peterborough', 'NNP'), ('.', '.')]
# going
# ('to', 'TO')
# Cambridge
# ('to', 'TO')
# Peterborough
# ('from', 'IN')
# (S
#   I/PRP
#   'm/VBP
#   sorry/JJ
#   ./.
#   The/DT
#   train/NN
#   needs/NNS
#   to/TO
#   going/VBG
#   (~[Location] to/TO Cambridge/NNP)
#   from/IN
#   (~[Location] Peterborough/NNP)
#   ./.)
# *****************************************
# Sorry about that,what time would you like to depart?
# [('Sorry', 'NN'), ('about', 'IN'), ('that', 'DT'), (',', ','), ('what', 'WP'), ('time', 'NN'), ('would', 'MD'), ('you', 'PRP'), ('like', 'IN'), ('to', 'TO'), ('depart', 'VB'), ('?', '.')]
# depart
# ('to', 'TO')
# (S
#   Sorry/NN
#   about/IN
#   that/DT
#   ,/,
#   what/WP
#   time/NN
#   would/MD
#   you/PRP
#   like/IN
#   to/TO
#   depart/VB
#   ?/.)
# *****************************************
# I would like to leave after 18:15.  Also, I would like to know the fare.
# [('I', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('leave', 'VB'), ('after', 'IN'), ('18:15', 'CD'), ('.', '.'), ('Also', 'RB'), (',', ','), ('I', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('know', 'VB'), ('the', 'DT'), ('fare', 'NN'), ('.', '.')]
# leave
# ('to', 'TO')
# know
# ('to', 'TO')
# (S
#   I/PRP
#   would/MD
#   like/VB
#   to/TO
#   leave/VB
#   after/IN
#   18:15/CD
#   ./.
#   Also/RB
#   ,/,
#   I/PRP
#   would/MD
#   like/VB
#   to/TO
#   know/VB
#   the/DT
#   fare/NN
#   ./.)
# *****************************************
# TR4005 departs Peterborough at 18:19 and arrives in Cambridge at 19:09. Total travel time is 50 minutes, and the fare is 13.20 GBP per person.
# [('TR4005', 'NNP'), ('departs', 'VBZ'), ('Peterborough', 'NNP'), ('at', 'IN'), ('18:19', 'CD'), ('and', 'CC'), ('arrives', 'NNS'), ('in', 'IN'), ('Cambridge', 'NNP'), ('at', 'IN'), ('19:09', 'CD'), ('.', '.'), ('Total', 'JJ'), ('travel', 'NN'), ('time', 'NN'), ('is', 'VBZ'), ('50', 'CD'), ('minutes', 'NNS'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('fare', 'NN'), ('is', 'VBZ'), ('13.20', 'CD'), ('GBP', 'NNP'), ('per', 'IN'), ('person', 'NN'), ('.', '.')]
# (S
#   (~[Location] TR4005/NNP)
#   departs/VBZ
#   (~[Location] Peterborough/NNP)
#   at/IN
#   18:19/CD
#   and/CC
#   arrives/NNS
#   in/IN
#   (~[Location] Cambridge/NNP)
#   at/IN
#   19:09/CD
#   ./.
#   Total/JJ
#   travel/NN
#   time/NN
#   is/VBZ
#   50/CD
#   minutes/NNS
#   ,/,
#   and/CC
#   the/DT
#   fare/NN
#   is/VBZ
#   13.20/CD
#   (~[Location] GBP/NNP)
#   per/IN
#   person/NN
#   ./.)
# *****************************************
# Great, thank you. Now, I need some information on college I can visit in the centre of town.
# [('Great', 'NNP'), (',', ','), ('thank', 'NN'), ('you', 'PRP'), ('.', '.'), ('Now', 'RB'), (',', ','), ('I', 'PRP'), ('need', 'VBP'), ('some', 'DT'), ('information', 'NN'), ('on', 'IN'), ('college', 'NN'), ('I', 'PRP'), ('can', 'MD'), ('visit', 'VB'), ('in', 'IN'), ('the', 'DT'), ('centre', 'NN'), ('of', 'IN'), ('town', 'NN'), ('.', '.')]
# (S
#   (~[Location] Great/NNP)
#   ,/,
#   thank/NN
#   you/PRP
#   ./.
#   Now/RB
#   ,/,
#   I/PRP
#   need/VBP
#   some/DT
#   information/NN
#   on/IN
#   college/NN
#   I/PRP
#   can/MD
#   visit/VB
#   in/IN
#   the/DT
#   centre/NN
#   of/IN
#   town/NN
#   ./.)
# *****************************************
# I have located several colleges in the area that have entrance fees ranging from free to 2 pounds. Is there a particular one you would like to visit?
# [('I', 'PRP'), ('have', 'VBP'), ('located', 'VBN'), ('several', 'JJ'), ('colleges', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('area', 'NN'), ('that', 'WDT'), ('have', 'VBP'), ('entrance', 'NN'), ('fees', 'NNS'), ('ranging', 'VBG'), ('from', 'IN'), ('free', 'JJ'), ('to', 'TO'), ('2', 'CD'), ('pounds', 'NNS'), ('.', '.'), ('Is', 'VBZ'), ('there', 'EX'), ('a', 'DT'), ('particular', 'JJ'), ('one', 'CD'), ('you', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('visit', 'VB'), ('?', '.')]
# free
# ('from', 'IN')
# 2
# ('to', 'TO')
# visit
# ('to', 'TO')
# (S
#   I/PRP
#   have/VBP
#   located/VBN
#   several/JJ
#   colleges/NNS
#   in/IN
#   the/DT
#   area/NN
#   that/WDT
#   have/VBP
#   entrance/NN
#   fees/NNS
#   ranging/VBG
#   from/IN
#   free/JJ
#   to/TO
#   2/CD
#   pounds/NNS
#   ./.
#   Is/VBZ
#   there/EX
#   a/DT
#   particular/JJ
#   one/CD
#   you/PRP
#   would/MD
#   like/VB
#   to/TO
#   visit/VB
#   ?/.)
# *****************************************
# I don't have one in particular. Can you give me a few examples?
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('have', 'VB'), ('one', 'CD'), ('in', 'IN'), ('particular', 'JJ'), ('.', '.'), ('Can', 'MD'), ('you', 'PRP'), ('give', 'VB'), ('me', 'PRP'), ('a', 'DT'), ('few', 'JJ'), ('examples', 'NNS'), ('?', '.')]
# (S
#   I/PRP
#   do/VBP
#   n't/RB
#   have/VB
#   one/CD
#   in/IN
#   particular/JJ
#   ./.
#   Can/MD
#   you/PRP
#   give/VB
#   me/PRP
#   a/DT
#   few/JJ
#   examples/NNS
#   ?/.)
# *****************************************
# Sure I have Corpus Christi in the city centre and Christ's College, which is very famous in the centre.
# [('Sure', 'JJ'), ('I', 'PRP'), ('have', 'VBP'), ('Corpus', 'NNP'), ('Christi', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('city', 'NN'), ('centre', 'NN'), ('and', 'CC'), ('Christ', 'NNP'), ("'s", 'POS'), ('College', 'NNP'), (',', ','), ('which', 'WDT'), ('is', 'VBZ'), ('very', 'RB'), ('famous', 'JJ'), ('in', 'IN'), ('the', 'DT'), ('centre', 'NN'), ('.', '.')]
# (S
#   Sure/JJ
#   I/PRP
#   have/VBP
#   (~[Location] Corpus/NNP)
#   (~[Location] Christi/NNP)
#   in/IN
#   the/DT
#   city/NN
#   centre/NN
#   and/CC
#   (~[Location] Christ/NNP)
#   's/POS
#   (~[Location] College/NNP)
#   ,/,
#   which/WDT
#   is/VBZ
#   very/RB
#   famous/JJ
#   in/IN
#   the/DT
#   centre/NN
#   ./.)
# *****************************************
# Can I get the address of Corpus Christi?
# [('Can', 'MD'), ('I', 'PRP'), ('get', 'VB'), ('the', 'DT'), ('address', 'NN'), ('of', 'IN'), ('Corpus', 'NNP'), ('Christi', 'NNP'), ('?', '.')]
# (S
#   Can/MD
#   I/PRP
#   get/VB
#   the/DT
#   address/NN
#   of/IN
#   (~[Location] Corpus/NNP)
#   (~[Location] Christi/NNP)
#   ?/.)
# *****************************************
# The address is king's parade, is there anything else I can do?
# [('The', 'DT'), ('address', 'NN'), ('is', 'VBZ'), ('king', 'VBG'), ("'s", 'POS'), ('parade', 'NN'), (',', ','), ('is', 'VBZ'), ('there', 'RB'), ('anything', 'NN'), ('else', 'JJ'), ('I', 'PRP'), ('can', 'MD'), ('do', 'VB'), ('?', '.')]
# (S
#   The/DT
#   address/NN
#   is/VBZ
#   king/VBG
#   's/POS
#   parade/NN
#   ,/,
#   is/VBZ
#   there/RB
#   anything/NN
#   else/JJ
#   I/PRP
#   can/MD
#   do/VB
#   ?/.)
# *****************************************
# No thank you. Thank you for your help.
# [('No', 'DT'), ('thank', 'NN'), ('you', 'PRP'), ('.', '.'), ('Thank', 'VB'), ('you', 'PRP'), ('for', 'IN'), ('your', 'PRP$'), ('help', 'NN'), ('.', '.')]
# (S
#   No/DT
#   thank/NN
#   you/PRP
#   ./.
#   Thank/VB
#   you/PRP
#   for/IN
#   your/PRP$
#   help/NN
#   ./.)
# *****************************************
# You're welcome.  I hope you enjoy your visit!  Goodbye.
# [('You', 'PRP'), ("'re", 'VBP'), ('welcome', 'JJ'), ('.', '.'), ('I', 'PRP'), ('hope', 'VBP'), ('you', 'PRP'), ('enjoy', 'VB'), ('your', 'PRP$'), ('visit', 'NN'), ('!', '.'), ('Goodbye', 'NNP'), ('.', '.')]
# (S
#   You/PRP
#   're/VBP
#   welcome/JJ
#   ./.
#   I/PRP
#   hope/VBP
#   you/PRP
#   enjoy/VB
#   your/PRP$
#   visit/NN
#   !/.
#   (~[Location] Goodbye/NNP)
#   ./.)
# *****************************************

# %%
# !pip install --upgrade setuptools --user
# Out:
# Collecting setuptools
#   Using cached https://files.pythonhosted.org/packages/9e/d5/444a443d890f09fc1ca1a2c3c9fc7e84cb148177b05ac94fe5084e3d9abb/setuptools-42.0.1-py2.py3-none-any.whl
# tensorflow 1.10.1 has requirement numpy<=1.14.5,>=1.13.3, but you'll have numpy 1.17.4 which is incompatible.
# tensorflow 1.10.1 has requirement setuptools<=39.1.0, but you'll have setuptools 42.0.1 which is incompatible.
# Installing collected packages: setuptools
# Successfully installed setuptools-42.0.1
# You are using pip version 18.0, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install pattern --user
# Out:
# Collecting pattern
#   Using cached https://files.pythonhosted.org/packages/1e/07/b0e61b6c818ed4b6145fe01d1c341223aa6cfbc3928538ad1f2b890924a3/Pattern-3.6.0.tar.gz
# Requirement already satisfied: future in /mnt/workspace/.local/lib/python3.5/site-packages (from pattern) (0.18.2)
# Collecting backports.csv (from pattern)
#   Using cached https://files.pythonhosted.org/packages/8e/26/a6bd68f13e0f38fbb643d6e497fc3462be83a0b6c4d43425c78bb51a7291/backports.csv-1.0.7-py2.py3-none-any.whl
# Collecting mysqlclient (from pattern)
#   Using cached https://files.pythonhosted.org/packages/d0/97/7326248ac8d5049968bf4ec708a5d3d4806e412a42e74160d7f266a3e03a/mysqlclient-1.4.6.tar.gz
#     Complete output from command python setup.py egg_info:
#     /bin/sh: 1: mysql_config: not found
#     /bin/sh: 1: mariadb_config: not found
#     /bin/sh: 1: mysql_config: not found
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-vtd8cjgf/mysqlclient/setup.py", line 16, in <module>
#         metadata, options = get_config()
#       File "/tmp/pip-install-vtd8cjgf/mysqlclient/setup_posix.py", line 61, in get_config
#         libs = mysql_config("libs")
#       File "/tmp/pip-install-vtd8cjgf/mysqlclient/setup_posix.py", line 29, in mysql_config
#         raise EnvironmentError("%s not found" % (_mysql_config_path,))
#     OSError: mysql_config not found
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-install-vtd8cjgf/mysqlclient/
# You are using pip version 18.0, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pattern.en import parse
from pattern.en import pprint
parse(string,
    tokenize=True,      # Split punctuation marks from words?
    tags=True,          # Parse part-of-speech tags? (NN, JJ, ...)
    chunks=True,        # Parse chunks? (NP, VP, PNP, ...)
    relations=False,    # Parse chunk relations? (-SBJ, -OBJ, ...)
    lemmata=False,      # Parse lemmata? (ate => eat)
    encoding='utf-8',   # Input string encoding.
    tagset=None         # Penn Treebank II (default) or UNIVERSAL.
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-538ea430b685> in <module>()
# ----> 1 from pattern.en import parse
#       2 from pattern.en import pprint
#       3 parse(string,
#       4     tokenize=True,      # Split punctuation marks from words?
#       5     tags=True,          # Parse part-of-speech tags? (NN, JJ, ...)
#
# ImportError: No module named 'pattern'
