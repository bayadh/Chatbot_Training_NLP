# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
nltk.download('averaged_perceptron_tagger')
import pandas as pd
import json
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /mnt/workspace/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Apply word tokenization and part-of-speech tagging

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %% [markdown]
# ## Open the json file and list the conversation

# %%
with open('train_data.json', 'r') as f:
    dict_json_weighted = json.load(f)
for i in range(len(dict_json_weighted[object_1]['log'])):
    print(str(i)+"-"+dict_json_weighted[object_1]['log'][i]['text'])
# Out:
# 0-I am looking for a train that departs from Peterborough and goes to Cambridge.
# 1-I have many trains available. What day would you like to leave?
# 2-We will be leaving on Sunday afternoon.
# 3-There are still many trains to pick from, can you narrow down a departure and arrival time frame?
# 4-Yes, it should leave after 20:15 and leave on monday, not sunday. Please give me a price, travel time, and arrival time for any train.
# 5-I have one leaving at 20:19 and arriving at 21:09. It is 13.20 pounds. Would you like me to book that for you.
# 6-Yes please. What is the travel time? I'll also need a hotel in the expensive price range. Can you help me with that as well?
# 7-Travel time is 50 minutes. I found 5 hotels you may like.  Do you have a star rating request or an area you prefer?
# 8-Yes, I'd like a 2 star rating and I'll need it to be in the east side of town.
# 9-I found one hotel that matches your criteria, It's the Express by Holiday Inn Cambridge. Would you like to book there?
# 10-Yes, I would like to book it for 3 people starting that same day for 4 nights.
# 11-I have you booked at the Express by Holiday Inn, three people for four nights starting on Monday. Your reference number is XPFOA5KT. Is there anything else you need?
# 12-That is all thank you goodbye.
# 13-Thank you for using Cambridge TownInfo centre. Have a wonderful day!

# %% [markdown]
# ## define the pattern

# %%
#pattern = 'NP: {<DT>?<JJ>*<NN>}'
pattern = '~[Location]:{<from>?<NNP>|<TO>?<NNP>}'

# %% [markdown]
# ## identify named entities and apply the parsing

# %%
object_1 = list(dict_json_weighted.keys())[4]
print(object_1)
location = 0;
time =0;
day=0;
for i in range(len(dict_json_weighted[object_1]['log'])):
    print(dict_json_weighted[object_1]['log'][i]['text'])
    sent = preprocess(dict_json_weighted[object_1]['log'][i]['text'])
    result= open(object_1+str(i)+".txt","w+")
    print(sent)
    for j in range(len(sent)):
        if sent[j][0]=='from'  :
            if location==0: 
                result.write("~[Location]\n")
                location=1;
            #print(sent[j+1][0])
            result.write("    "+sent[j+1][0]+"\n")
            #print (sent[j])
        elif sent[j][0]=='to' and (sent[j+1][1]!='VBZ' and sent[j+1][1]!='VB' and sent[j+1][1]!='NN'):
            if location==0: 
                result.write("~[Location]\n")
                location=1;
            result.write("    "+sent[j+1][0]+"\n")
            #print (sent[j])
        elif (sent[j][0]=='at' and sent[j+1][1]=='CD') or (sent[j][0]=='after' and sent[j+1][1]=='CD'):
            if time==0: 
                result.write("~[Time]\n")
                time=1;
            result.write("    "+sent[j+1][0]+"\n")
    cp = nltk.RegexpParser(pattern)
    cs = cp.parse(sent)
    print(cs)
    print('*****************************************')
# Out:
# MUL0772.json
# I am looking for a train that departs from Peterborough and goes to Cambridge.
# [('I', 'PRP'), ('am', 'VBP'), ('looking', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('train', 'NN'), ('that', 'WDT'), ('departs', 'VBZ'), ('from', 'IN'), ('Peterborough', 'NNP'), ('and', 'CC'), ('goes', 'VBZ'), ('to', 'TO'), ('Cambridge', 'NNP'), ('.', '.')]
# (S
#   I/PRP
#   am/VBP
#   looking/VBG
#   for/IN
#   a/DT
#   train/NN
#   that/WDT
#   departs/VBZ
#   from/IN
#   (~[Location] Peterborough/NNP)
#   and/CC
#   goes/VBZ
#   (~[Location] to/TO Cambridge/NNP)
#   ./.)
# *****************************************
# I have many trains available. What day would you like to leave?
# [('I', 'PRP'), ('have', 'VBP'), ('many', 'JJ'), ('trains', 'NNS'), ('available', 'JJ'), ('.', '.'), ('What', 'WP'), ('day', 'NN'), ('would', 'MD'), ('you', 'PRP'), ('like', 'IN'), ('to', 'TO'), ('leave', 'VB'), ('?', '.')]
# (S
#   I/PRP
#   have/VBP
#   many/JJ
#   trains/NNS
#   available/JJ
#   ./.
#   What/WP
#   day/NN
#   would/MD
#   you/PRP
#   like/IN
#   to/TO
#   leave/VB
#   ?/.)
# *****************************************
# We will be leaving on Sunday afternoon.
# [('We', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('leaving', 'VBG'), ('on', 'IN'), ('Sunday', 'NNP'), ('afternoon', 'NN'), ('.', '.')]
# (S
#   We/PRP
#   will/MD
#   be/VB
#   leaving/VBG
#   on/IN
#   (~[Location] Sunday/NNP)
#   afternoon/NN
#   ./.)
# *****************************************
# There are still many trains to pick from, can you narrow down a departure and arrival time frame?
# [('There', 'EX'), ('are', 'VBP'), ('still', 'RB'), ('many', 'JJ'), ('trains', 'NNS'), ('to', 'TO'), ('pick', 'VB'), ('from', 'IN'), (',', ','), ('can', 'MD'), ('you', 'PRP'), ('narrow', 'VB'), ('down', 'RP'), ('a', 'DT'), ('departure', 'NN'), ('and', 'CC'), ('arrival', 'JJ'), ('time', 'NN'), ('frame', 'NN'), ('?', '.')]
# (S
#   There/EX
#   are/VBP
#   still/RB
#   many/JJ
#   trains/NNS
#   to/TO
#   pick/VB
#   from/IN
#   ,/,
#   can/MD
#   you/PRP
#   narrow/VB
#   down/RP
#   a/DT
#   departure/NN
#   and/CC
#   arrival/JJ
#   time/NN
#   frame/NN
#   ?/.)
# *****************************************
# Yes, it should leave after 20:15 and leave on monday, not sunday. Please give me a price, travel time, and arrival time for any train.
# [('Yes', 'UH'), (',', ','), ('it', 'PRP'), ('should', 'MD'), ('leave', 'VB'), ('after', 'IN'), ('20:15', 'CD'), ('and', 'CC'), ('leave', 'VB'), ('on', 'IN'), ('monday', 'NN'), (',', ','), ('not', 'RB'), ('sunday', 'JJ'), ('.', '.'), ('Please', 'NNP'), ('give', 'VB'), ('me', 'PRP'), ('a', 'DT'), ('price', 'NN'), (',', ','), ('travel', 'NN'), ('time', 'NN'), (',', ','), ('and', 'CC'), ('arrival', 'JJ'), ('time', 'NN'), ('for', 'IN'), ('any', 'DT'), ('train', 'NN'), ('.', '.')]
# (S
#   Yes/UH
#   ,/,
#   it/PRP
#   should/MD
#   leave/VB
#   after/IN
#   20:15/CD
#   and/CC
#   leave/VB
#   on/IN
#   monday/NN
#   ,/,
#   not/RB
#   sunday/JJ
#   ./.
#   (~[Location] Please/NNP)
#   give/VB
#   me/PRP
#   a/DT
#   price/NN
#   ,/,
#   travel/NN
#   time/NN
#   ,/,
#   and/CC
#   arrival/JJ
#   time/NN
#   for/IN
#   any/DT
#   train/NN
#   ./.)
# *****************************************
# I have one leaving at 20:19 and arriving at 21:09. It is 13.20 pounds. Would you like me to book that for you.
# [('I', 'PRP'), ('have', 'VBP'), ('one', 'CD'), ('leaving', 'VBG'), ('at', 'IN'), ('20:19', 'CD'), ('and', 'CC'), ('arriving', 'VBG'), ('at', 'IN'), ('21:09', 'CD'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('13.20', 'CD'), ('pounds', 'NNS'), ('.', '.'), ('Would', 'MD'), ('you', 'PRP'), ('like', 'VB'), ('me', 'PRP'), ('to', 'TO'), ('book', 'NN'), ('that', 'IN'), ('for', 'IN'), ('you', 'PRP'), ('.', '.')]
# (S
#   I/PRP
#   have/VBP
#   one/CD
#   leaving/VBG
#   at/IN
#   20:19/CD
#   and/CC
#   arriving/VBG
#   at/IN
#   21:09/CD
#   ./.
#   It/PRP
#   is/VBZ
#   13.20/CD
#   pounds/NNS
#   ./.
#   Would/MD
#   you/PRP
#   like/VB
#   me/PRP
#   to/TO
#   book/NN
#   that/IN
#   for/IN
#   you/PRP
#   ./.)
# *****************************************
# Yes please. What is the travel time? I'll also need a hotel in the expensive price range. Can you help me with that as well?
# [('Yes', 'UH'), ('please', 'NN'), ('.', '.'), ('What', 'WP'), ('is', 'VBZ'), ('the', 'DT'), ('travel', 'NN'), ('time', 'NN'), ('?', '.'), ('I', 'PRP'), ("'ll", 'MD'), ('also', 'RB'), ('need', 'VB'), ('a', 'DT'), ('hotel', 'NN'), ('in', 'IN'), ('the', 'DT'), ('expensive', 'JJ'), ('price', 'NN'), ('range', 'NN'), ('.', '.'), ('Can', 'MD'), ('you', 'PRP'), ('help', 'VB'), ('me', 'PRP'), ('with', 'IN'), ('that', 'DT'), ('as', 'RB'), ('well', 'RB'), ('?', '.')]
# (S
#   Yes/UH
#   please/NN
#   ./.
#   What/WP
#   is/VBZ
#   the/DT
#   travel/NN
#   time/NN
#   ?/.
#   I/PRP
#   'll/MD
#   also/RB
#   need/VB
#   a/DT
#   hotel/NN
#   in/IN
#   the/DT
#   expensive/JJ
#   price/NN
#   range/NN
#   ./.
#   Can/MD
#   you/PRP
#   help/VB
#   me/PRP
#   with/IN
#   that/DT
#   as/RB
#   well/RB
#   ?/.)
# *****************************************
# Travel time is 50 minutes. I found 5 hotels you may like.  Do you have a star rating request or an area you prefer?
# [('Travel', 'NN'), ('time', 'NN'), ('is', 'VBZ'), ('50', 'CD'), ('minutes', 'NNS'), ('.', '.'), ('I', 'PRP'), ('found', 'VBD'), ('5', 'CD'), ('hotels', 'NNS'), ('you', 'PRP'), ('may', 'MD'), ('like', 'VB'), ('.', '.'), ('Do', 'VB'), ('you', 'PRP'), ('have', 'VB'), ('a', 'DT'), ('star', 'NN'), ('rating', 'NN'), ('request', 'NN'), ('or', 'CC'), ('an', 'DT'), ('area', 'NN'), ('you', 'PRP'), ('prefer', 'VBP'), ('?', '.')]
# (S
#   Travel/NN
#   time/NN
#   is/VBZ
#   50/CD
#   minutes/NNS
#   ./.
#   I/PRP
#   found/VBD
#   5/CD
#   hotels/NNS
#   you/PRP
#   may/MD
#   like/VB
#   ./.
#   Do/VB
#   you/PRP
#   have/VB
#   a/DT
#   star/NN
#   rating/NN
#   request/NN
#   or/CC
#   an/DT
#   area/NN
#   you/PRP
#   prefer/VBP
#   ?/.)
# *****************************************
# Yes, I'd like a 2 star rating and I'll need it to be in the east side of town.
# [('Yes', 'UH'), (',', ','), ('I', 'PRP'), ("'d", 'MD'), ('like', 'VB'), ('a', 'DT'), ('2', 'CD'), ('star', 'NN'), ('rating', 'NN'), ('and', 'CC'), ('I', 'PRP'), ("'ll", 'MD'), ('need', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('be', 'VB'), ('in', 'IN'), ('the', 'DT'), ('east', 'JJ'), ('side', 'NN'), ('of', 'IN'), ('town', 'NN'), ('.', '.')]
# (S
#   Yes/UH
#   ,/,
#   I/PRP
#   'd/MD
#   like/VB
#   a/DT
#   2/CD
#   star/NN
#   rating/NN
#   and/CC
#   I/PRP
#   'll/MD
#   need/VB
#   it/PRP
#   to/TO
#   be/VB
#   in/IN
#   the/DT
#   east/JJ
#   side/NN
#   of/IN
#   town/NN
#   ./.)
# *****************************************
# I found one hotel that matches your criteria, It's the Express by Holiday Inn Cambridge. Would you like to book there?
# [('I', 'PRP'), ('found', 'VBD'), ('one', 'CD'), ('hotel', 'NN'), ('that', 'WDT'), ('matches', 'VBZ'), ('your', 'PRP$'), ('criteria', 'NNS'), (',', ','), ('It', 'PRP'), ("'s", 'VBZ'), ('the', 'DT'), ('Express', 'NNP'), ('by', 'IN'), ('Holiday', 'NNP'), ('Inn', 'NNP'), ('Cambridge', 'NNP'), ('.', '.'), ('Would', 'MD'), ('you', 'PRP'), ('like', 'VB'), ('to', 'TO'), ('book', 'NN'), ('there', 'RB'), ('?', '.')]
# (S
#   I/PRP
#   found/VBD
#   one/CD
#   hotel/NN
#   that/WDT
#   matches/VBZ
#   your/PRP$
#   criteria/NNS
#   ,/,
#   It/PRP
#   's/VBZ
#   the/DT
#   (~[Location] Express/NNP)
#   by/IN
#   (~[Location] Holiday/NNP)
#   (~[Location] Inn/NNP)
#   (~[Location] Cambridge/NNP)
#   ./.
#   Would/MD
#   you/PRP
#   like/VB
#   to/TO
#   book/NN
#   there/RB
#   ?/.)
# *****************************************
# Yes, I would like to book it for 3 people starting that same day for 4 nights.
# [('Yes', 'UH'), (',', ','), ('I', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('book', 'NN'), ('it', 'PRP'), ('for', 'IN'), ('3', 'CD'), ('people', 'NNS'), ('starting', 'VBG'), ('that', 'IN'), ('same', 'JJ'), ('day', 'NN'), ('for', 'IN'), ('4', 'CD'), ('nights', 'NNS'), ('.', '.')]
# (S
#   Yes/UH
#   ,/,
#   I/PRP
#   would/MD
#   like/VB
#   to/TO
#   book/NN
#   it/PRP
#   for/IN
#   3/CD
#   people/NNS
#   starting/VBG
#   that/IN
#   same/JJ
#   day/NN
#   for/IN
#   4/CD
#   nights/NNS
#   ./.)
# *****************************************
# I have you booked at the Express by Holiday Inn, three people for four nights starting on Monday. Your reference number is XPFOA5KT. Is there anything else you need?
# [('I', 'PRP'), ('have', 'VBP'), ('you', 'PRP'), ('booked', 'VBN'), ('at', 'IN'), ('the', 'DT'), ('Express', 'NNP'), ('by', 'IN'), ('Holiday', 'NNP'), ('Inn', 'NNP'), (',', ','), ('three', 'CD'), ('people', 'NNS'), ('for', 'IN'), ('four', 'CD'), ('nights', 'NNS'), ('starting', 'VBG'), ('on', 'IN'), ('Monday', 'NNP'), ('.', '.'), ('Your', 'PRP$'), ('reference', 'NN'), ('number', 'NN'), ('is', 'VBZ'), ('XPFOA5KT', 'NNP'), ('.', '.'), ('Is', 'VBZ'), ('there', 'RB'), ('anything', 'NN'), ('else', 'RB'), ('you', 'PRP'), ('need', 'VBP'), ('?', '.')]
# (S
#   I/PRP
#   have/VBP
#   you/PRP
#   booked/VBN
#   at/IN
#   the/DT
#   (~[Location] Express/NNP)
#   by/IN
#   (~[Location] Holiday/NNP)
#   (~[Location] Inn/NNP)
#   ,/,
#   three/CD
#   people/NNS
#   for/IN
#   four/CD
#   nights/NNS
#   starting/VBG
#   on/IN
#   (~[Location] Monday/NNP)
#   ./.
#   Your/PRP$
#   reference/NN
#   number/NN
#   is/VBZ
#   (~[Location] XPFOA5KT/NNP)
#   ./.
#   Is/VBZ
#   there/RB
#   anything/NN
#   else/RB
#   you/PRP
#   need/VBP
#   ?/.)
# *****************************************
# That is all thank you goodbye.
# [('That', 'DT'), ('is', 'VBZ'), ('all', 'DT'), ('thank', 'NN'), ('you', 'PRP'), ('goodbye', 'VBP'), ('.', '.')]
# (S That/DT is/VBZ all/DT thank/NN you/PRP goodbye/VBP ./.)
# *****************************************
# Thank you for using Cambridge TownInfo centre. Have a wonderful day!
# [('Thank', 'NNP'), ('you', 'PRP'), ('for', 'IN'), ('using', 'VBG'), ('Cambridge', 'NNP'), ('TownInfo', 'NNP'), ('centre', 'NN'), ('.', '.'), ('Have', 'VBP'), ('a', 'DT'), ('wonderful', 'JJ'), ('day', 'NN'), ('!', '.')]
# (S
#   (~[Location] Thank/NNP)
#   you/PRP
#   for/IN
#   using/VBG
#   (~[Location] Cambridge/NNP)
#   (~[Location] TownInfo/NNP)
#   centre/NN
#   ./.
#   Have/VBP
#   a/DT
#   wonderful/JJ
#   day/NN
#   !/.)
# *****************************************
